# %% [markdown]
# # Python Programming Language, Machine Learning Libraries
# ---

# %% [markdown]
# ## Numpy
#
# #### Used for working with arrays.
# ####  offers various tools including:
#     - Mathematical Functions
#     - Random Number Generators
#
# #### Documentation availabe: https://numpy.org/doc/stable/

# %% [markdown]
# ## Pandas
#
#
# ####  Used for data cleaning and analysis.
# ####  It has features which are used for: exploring, cleaning, transforming and visualizing from data.
#     - Exploring
#     - Cleaning
#     - Transforming
#     - Visualizing
# #### Documentation availabe: https://pandas.pydata.org/docs/user_guide/index.html
# #### Installing Pandas:

# %%
# !pip install pandas

# %% [markdown]
# ![Pandas.jpeg](attachment:Pandas.jpeg)

# %% [markdown]
# ## Matplotlib
#
# #### Used to create various plot types:
#     - Line plots (plt.plot)
#     - Scatter plots (plt.scatter)
#     - Histograms (plt.hist)
#     - Bar plots (plt.bar)
#     - Create figure objects (fig, ax = plt.subplots())
#
# #### Documentation availabe: https://matplotlib.org/stable/plot_types/index

# %% [markdown]
# ![Matplotlib.png](attachment:Matplotlib.png)

# %% [markdown]
# ## Seaborn
#
#
# #### Another visualization tool, based on `matplotlib`
# #### Provides a variety of visualization patterns.
# #### Easier than matplotlib in terms of syntax.
# #### Documentation availabe: https://seaborn.pydata.org/

# %% [markdown]
# ## scikit-learn (sklearn)
#
#
# ####  A free software machine learning library for the Python programming language.
#     - Classification
#     - Regression
#     - Clustering
#     - Pre-processing
#     - Dimensionality Reduction
#     - Model Selection
# #### Documentation availabe: https://scikit-learn.org/
